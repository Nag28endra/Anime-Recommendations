# %%
import pandas as pd

df = pd.read_csv("../data/anime_data.csv")
df.head(50)
# Out:
#                                                 Title  Episodes  \
# 0                                        Cowboy Bebop      26.0
# 1                     Cowboy Bebop: Tengoku no Tobira       1.0
# 2                                              Trigun      26.0
# 3                                  Witch Hunter Robin      26.0
# 4                                      Bouken Ou Beet      52.0
# 5                                        Eyeshield 21     145.0
# 6                                Hachimitsu to Clover      24.0
# 7                          Hungry Heart: Wild Striker      52.0
# 8                              Initial D Fourth Stage      24.0
# 9                                             Monster      74.0
# 10                                             Naruto     220.0
# 11                                          One Piece       NaN
# 12                                 Tennis no Oujisama     178.0
# 13                                   Ring ni Kakero 1      12.0
# ...
